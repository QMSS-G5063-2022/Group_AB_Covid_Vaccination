# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/owid-covid-data.csv")

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df = df[["location","people_vaccinated","date","people_fully_vaccinated","population"]]

# %%
rslt_df = df[df['date'] > "2022-01-01"]

# %%
rslt_df
# Out:
#            location  people_vaccinated        date  people_fully_vaccinated  \
# 678     Afghanistan                NaN  2022-01-02                      NaN
# 679     Afghanistan                NaN  2022-01-03                      NaN
# 680     Afghanistan                NaN  2022-01-04                      NaN
# 681     Afghanistan                NaN  2022-01-05                      NaN
# 682     Afghanistan                NaN  2022-01-06                      NaN
# ...             ...                ...         ...                      ...
# 179213     Zimbabwe          5734219.0  2022-04-11                3600666.0
# 179214     Zimbabwe          5753797.0  2022-04-12                3604044.0
# 179215     Zimbabwe          5756469.0  2022-04-13                3605713.0
# 179216     Zimbabwe          5767690.0  2022-04-14                3611223.0
# 179217     Zimbabwe                NaN  2022-04-15                      NaN
#
#         population
# 678     39835428.0
# 679     39835428.0
# 680     39835428.0
# 681     39835428.0
# 682     39835428.0
# ...            ...
# 179213  15092171.0
# 179214  15092171.0
# 179215  15092171.0
# 179216  15092171.0
# 179217  15092171.0
#
# [24566 rows x 5 columns]

# %%
df1 = rslt_df.dropna()

# %%
df1
# Out:
#            location  people_vaccinated        date  people_fully_vaccinated  \
# 685     Afghanistan          4358570.0  2022-01-09                3809353.0
# 687     Afghanistan          4378818.0  2022-01-11                3814837.0
# 689     Afghanistan          4405897.0  2022-01-13                3823786.0
# 693     Afghanistan          4432926.0  2022-01-17                3832821.0
# 695     Afghanistan          4450211.0  2022-01-19                3836731.0
# ...             ...                ...         ...                      ...
# 179212     Zimbabwe          5721969.0  2022-04-10                3599536.0
# 179213     Zimbabwe          5734219.0  2022-04-11                3600666.0
# 179214     Zimbabwe          5753797.0  2022-04-12                3604044.0
# 179215     Zimbabwe          5756469.0  2022-04-13                3605713.0
# 179216     Zimbabwe          5767690.0  2022-04-14                3611223.0
#
#         population
# 685     39835428.0
# 687     39835428.0
# 689     39835428.0
# 693     39835428.0
# 695     39835428.0
# ...            ...
# 179212  15092171.0
# 179213  15092171.0
# 179214  15092171.0
# 179215  15092171.0
# 179216  15092171.0
#
# [9520 rows x 5 columns]

# %%
g = df1.groupby('location')
g.tail(1)
# Out:
#                  location  people_vaccinated        date  \
# 780           Afghanistan       5.246981e+06  2022-04-14
# 1573               Africa       2.916833e+08  2022-04-14
# 2354              Albania       1.287062e+06  2022-04-14
# 3099              Algeria       7.461932e+06  2022-03-09
# 3907              Andorra       5.785000e+04  2022-04-10
# ...                   ...                ...         ...
# 176125  Wallis and Futuna       6.483000e+03  2022-03-21
# 176964              World       5.117126e+09  2022-04-14
# 177692              Yemen       6.496730e+05  2022-04-06
# 178413             Zambia       2.487149e+06  2022-02-27
# 179216           Zimbabwe       5.767690e+06  2022-04-14
#
#         people_fully_vaccinated    population
# 780                4.595506e+06  3.983543e+07
# 1573               2.217818e+08  1.373486e+09
# 2354               1.223943e+06  2.872934e+06
# 3099               6.110712e+06  4.461663e+07
# 3907               5.340600e+04  7.735400e+04
# ...                         ...           ...
# 176125             6.457000e+03  1.109400e+04
# 176964             4.616144e+09  7.874966e+09
# 177692             4.115010e+05  3.049064e+07
# 178413             1.862614e+06  1.892066e+07
# 179216             3.611223e+06  1.509217e+07
#
# [218 rows x 5 columns]

# %%
df2 = g.tail(1)

# %%
df2
# Out:
#                  location  people_vaccinated        date  \
# 780           Afghanistan       5.246981e+06  2022-04-14
# 1573               Africa       2.916833e+08  2022-04-14
# 2354              Albania       1.287062e+06  2022-04-14
# 3099              Algeria       7.461932e+06  2022-03-09
# 3907              Andorra       5.785000e+04  2022-04-10
# ...                   ...                ...         ...
# 176125  Wallis and Futuna       6.483000e+03  2022-03-21
# 176964              World       5.117126e+09  2022-04-14
# 177692              Yemen       6.496730e+05  2022-04-06
# 178413             Zambia       2.487149e+06  2022-02-27
# 179216           Zimbabwe       5.767690e+06  2022-04-14
#
#         people_fully_vaccinated    population
# 780                4.595506e+06  3.983543e+07
# 1573               2.217818e+08  1.373486e+09
# 2354               1.223943e+06  2.872934e+06
# 3099               6.110712e+06  4.461663e+07
# 3907               5.340600e+04  7.735400e+04
# ...                         ...           ...
# 176125             6.457000e+03  1.109400e+04
# 176964             4.616144e+09  7.874966e+09
# 177692             4.115010e+05  3.049064e+07
# 178413             1.862614e+06  1.892066e+07
# 179216             3.611223e+06  1.509217e+07
#
# [218 rows x 5 columns]

# %%
df3 = df2[["location","people_vaccinated","people_fully_vaccinated","population"]]

# %%
df3["first"] = df3["people_vaccinated"]/df3["population"]
df3["fully"] = df3["people_fully_vaccinated"]/df3["population"]

# %%
df3 = df3[["location","first","fully"]]

# %%
df3.rename(columns={'location':'country'}, inplace=True)
df3 = df3.reset_index()
df3 = df3[["country","first","fully"]]

# %%
df3
# Out:
#                country     first     fully
# 0          Afghanistan  0.131716  0.115362
# 1               Africa  0.212367  0.161474
# 2              Albania  0.447996  0.426025
# 3              Algeria  0.167246  0.136960
# 4              Andorra  0.747860  0.690410
# ..                 ...       ...       ...
# 213  Wallis and Futuna  0.584370  0.582026
# 214              World  0.649797  0.586180
# 215              Yemen  0.021307  0.013496
# 216             Zambia  0.131452  0.098443
# 217           Zimbabwe  0.382164  0.239278
#
# [218 rows x 3 columns]

# %%
from pathlib import Path  
filepath = Path('/Users/nina/Documents/GitHub/Learning-D3.js-4-Mapping/chapter-10/data/covid.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df3.to_csv(filepath)

# %%
# Graph3 data cleaning

df4 = pd.read_csv("covids.csv")
df5 = pd.read_csv("country_income.csv")
df6 = pd.read_csv("owid-covid-data.csv")
df6 = df6[["location","population"]]
df6 = df6.drop_duplicates()
df6=df6.rename(columns = {'location':'country'})

# %%
df7 = pd.merge(df4, df6, on="country", how="left")
df7
# Out:
#                country     first     fully  population
# 0          Afghanistan  0.131716  0.115362  39835428.0
# 1              Albania  0.447996  0.426025   2872934.0
# 2              Algeria  0.167246  0.136960  44616626.0
# 3              Andorra  0.747860  0.690410     77354.0
# 4               Angola  0.347733  0.180562  33933611.0
# ..                 ...       ...       ...         ...
# 202            Vietnam  0.814385  0.792045  98168829.0
# 203  Wallis and Futuna  0.584370  0.582026     11094.0
# 204              Yemen  0.021307  0.013496  30490639.0
# 205             Zambia  0.131452  0.098443  18920657.0
# 206           Zimbabwe  0.382164  0.239278  15092171.0
#
# [207 rows x 4 columns]

# %%
df8 = pd.merge(df7, df5, on="country", how="right")
df8
# Out:
#           country     first     fully  population         Income group
# 0           Aruba  0.822380  0.762461    107195.0          High income
# 1     Afghanistan  0.131716  0.115362  39835428.0           Low income
# 2          Angola  0.347733  0.180562  33933611.0  Lower middle income
# 3         Albania  0.447996  0.426025   2872934.0  Upper middle income
# 4         Andorra  0.747860  0.690410     77354.0          High income
# ..            ...       ...       ...         ...                  ...
# 212        Kosovo  0.506237  0.460891   1782115.0  Upper middle income
# 213         Yemen  0.021307  0.013496  30490639.0           Low income
# 214  South Africa  0.351675  0.302068  60041996.0  Upper middle income
# 215        Zambia  0.131452  0.098443  18920657.0  Lower middle income
# 216      Zimbabwe  0.382164  0.239278  15092171.0  Lower middle income
#
# [217 rows x 5 columns]

# %%
df8 = df8.dropna()
df8
# Out:
#           country     first     fully  population         Income group
# 0           Aruba  0.822380  0.762461    107195.0          High income
# 1     Afghanistan  0.131716  0.115362  39835428.0           Low income
# 2          Angola  0.347733  0.180562  33933611.0  Lower middle income
# 3         Albania  0.447996  0.426025   2872934.0  Upper middle income
# 4         Andorra  0.747860  0.690410     77354.0          High income
# ..            ...       ...       ...         ...                  ...
# 212        Kosovo  0.506237  0.460891   1782115.0  Upper middle income
# 213         Yemen  0.021307  0.013496  30490639.0           Low income
# 214  South Africa  0.351675  0.302068  60041996.0  Upper middle income
# 215        Zambia  0.131452  0.098443  18920657.0  Lower middle income
# 216      Zimbabwe  0.382164  0.239278  15092171.0  Lower middle income
#
# [186 rows x 5 columns]

# %%
from pathlib import Path  
filepath = Path('/Users/nina/Documents/QMSS5063/Group_AB_Covid_Vaccination/rshiny/src/www/data/graph3_cleaned.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df8.to_csv(filepath)
